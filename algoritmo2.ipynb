# %%
# Lista com espaços 'vazios' para adicionar nomes de guerra
pa = [['*', '*', '*', '*', '*', '*', '*'], ['*', '*', '*', '*', '*', '*', '*'], ['*', '*', '*', '*', '*', '*', '*']]
ent = 0  # Variável que recebe valor do usuário para selecionar opção no menu


# Loop While utilizado para manter o menu atualizando
while ent < 999:
    
    # Imprimindo texto do menu
    print('Escolha:')
    print('1-Informar posição de aluno no dispositivo.')
    print('2-Liberar posição no dispositivo.')
    print('3-Verificar a ocupação no dispositivo.')
    print('4-Listar alunos no dispositivo de formatura.')
    print('9-Sair do programa.\n')
    
    # Recebendo valor do usuário
    ent = int(input('>'))
    print('\n')

    # Se o usuario selecionar opção 2
    if ent == 1:
        
        # Imprimi os títulos e instruções
        print('[Opção 1] Insere aluno no dispositivo')
        print('----------------------------------------')
        print('Digite 999 no valor para encerrar')
        
        # Recebe o valor da linha selecionada pelo usuário
        linha = int(input('Linha: '))
        
        # Estabele condição para encerrar o programa caso o valor lido seja 999
        if linha == 999:
            print('\n')
            
        # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
        elif linha > 7 or linha < 1:
            print('O máximo de linhas existentes na matriz são 7 e o mínimo 1!\n')  
        
        else:
            # Recebe o valor da coluna selecionada pelo usuário
            coluna = int(input('Coluna: '))

            # Estabele condição para encerrar o programa caso o valor lido seja 999
            if coluna == 999:
                print('\n')
                    
            # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
            elif coluna > 3 or coluna < 1: 
                print('O máximo de colunas existentes na matriz são 3 e o mínimo 1!\n')
            
            else:
                # Recebe o nome de guerra que será adicionado à matriz
                nome = str(input('Nome do Aluno: '))

                # Estabele condição para encerrar o programa caso o valor lido seja 999
                if nome == '999':
                    print('\n')

                # Se nenhum impecílio ocorrer o nome é adicionado a Matriz
                else:    
                    pa[coluna-1][linha-1] = nome
                    print(f'{linha} x {coluna} destinada a {nome} \n')
    
    # Se o usuário selecionar a opção 2
    elif ent == 2:
        
        # Imprimi os títulos e instruções
        print('[Opção 2] Libera posição do dispositivo')
        print('----------------------------------------')
        print('Digite 999 no valor para encerrar')
        
        # Recebe o valor da linha selecionada pelo usuário
        linha = int(input('Linha: '))
        
        # Estabele condição para encerrar o programa caso o valor lido seja 999
        if linha == 999:
            print('\n')
            
        # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
        elif linha > 7 or linha < 1:
            print('O máximo de linhas existentes na matriz são 7 e o mínimo 1!\n') 
        
        else:
            # Recebe o valor da coluna selecionada pelo usuário
            coluna = int(input('Coluna: '))

            # Estabele condição para encerrar o programa caso o valor lido seja 999
            if coluna == 999:
                print('\n')

            # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
            elif coluna > 3 or coluna < 1: 
                print('O máximo de colunas existentes na matriz são 3 e o mínimo 1!\n')

            # Se nenhum impecílio ocorrer o nome é adicionado a Matriz
            else:
                pa[coluna-1][linha-1] = '*'
                print(f'{linha} x {coluna} Liberada\n')
    
    # Se o usuário selecionar a opção 3
    elif ent == 3:
        
        # Imprimi o título
        print('[Opção 3] Exibe ocupação no dispositivo')
        print('----------------------------------------')
        
        # Recebe o nome de guerra que será adicionado à matriz
        nome_ = str(input('Nome: '))
        
        # Declarando um vetor 
        v = []
        
        # Gerando um laço for que passa pelas 3 colunas da matriz
        for j in range(3):
            x += 1
            # Outro laço for para passar por cada linha da matriz
            for i in range(7):
                # Verificando se o nome se encontra na matriz
                c = v.count(f'{nome_}')
                y += 1
                # Se o nome estiver na matriz
                if c == 1:
                    # O loop encerra
                    break
                # Monta um vetor com os valores da matriz até encontrar o nome desejado
                v.append(pa[j][i])
        
        # Se o nome estiver na matriz
        if c == 1:
            # Usando a função 'posicao' que recebe o valor que é retornado pelo tamanho do vetor v.
            posicao(len(v))
        
        # Se não estiver
        else:
            print(f'O nome {nome_} não foi encontrado na matriz.\n')
    
    # Se o usuário selecionar a opção 4
    elif ent == 4:
        
        # Imprimi o título
        print('[Opção 4] Listar alunos no dispositivo')
        print('----------------------------------------')
        
        # Imprimi uma lista 'formatada' com os valores da matriz e os valores das linhas e colunas
        print('             |P A L A N Q U E|\n            -----------------\n')
        print('        1               2               3')
        print('        -               -               -')
        print(f'1       {pa[0][0]:16}{pa[1][0]:16}{pa[2][0]}')
        print(f'2       {pa[0][1]:16}{pa[1][1]:16}{pa[2][1]}')
        print(f'3       {pa[0][2]:16}{pa[1][2]:16}{pa[2][2]}')
        print(f'4       {pa[0][3]:16}{pa[1][3]:16}{pa[2][3]}')
        print(f'5       {pa[0][4]:16}{pa[1][4]:16}{pa[2][4]}')
        print(f'6       {pa[0][5]:16}{pa[1][5]:16}{pa[2][5]}')
        print(f'7       {pa[0][6]:16}{pa[1][6]:16}{pa[2][6]}')
        print('\n(*) = vazio\n')
    
    # Se o usuário selecionar a opção 9
    elif ent == 9:
        
        # Imprimi a despedida e encerra o programa.
        print('### Fim do Programa ###')
        break
    
    # Se o usuário selecionar um valor que não está descrito no menu 
    elif 4 < ent < 9 or ent > 9:
        
        # Imprimi o aviso e reinicia a seleção
        print('-------------------------------')
        print('| Informe um valor existente! |')
        print('-------------------------------\n')
# Out:
# Escolha:
# 1-Informar posição de aluno no dispositivo.
# 2-Liberar posição no dispositivo.
# 3-Verificar a ocupação no dispositivo.
# 4-Listar alunos no dispositivo de formatura.
# 9-Sair do programa.
#
# >1
#
#
# [Opção 1] Insere aluno no dispositivo
# ----------------------------------------
# Digite 999 no valor para encerrar
# Linha: 1
# Coluna: 1
# Nome do Aluno: 999
#
#
# Escolha:
# 1-Informar posição de aluno no dispositivo.
# 2-Liberar posição no dispositivo.
# 3-Verificar a ocupação no dispositivo.
# 4-Listar alunos no dispositivo de formatura.
# 9-Sair do programa.
#
# >2
#
#
# [Opção 2] Libera posição do dispositivo
# ----------------------------------------
# Digite 999 no valor para encerrar
# Linha: 1
# Coluna: 999
#
#
# Escolha:
# 1-Informar posição de aluno no dispositivo.
# 2-Liberar posição no dispositivo.
# 3-Verificar a ocupação no dispositivo.
# 4-Listar alunos no dispositivo de formatura.
# 9-Sair do programa.
#
# >2
#
#
# ...

# %%
# Função que imprimi a localização do Nome de Guerra
def posicao(a):
    if a == 1:
        return'Localização do Aluno: 1 x 1'
    if a == 2:
        return'Localização do Aluno: 2 x 1'
    if a == 3:
        return'Localização do Aluno: 3 x 1'
    if a == 4:
        return'Localização do Aluno: 4 x 1'
    if a == 5:
        return'Localização do Aluno: 5 x 1'
    if a == 6:
        return'Localização do Aluno: 6 x 1'
    if a == 7:
        return'Localização do Aluno: 7 x 1'
    if a == 8:
        return'Localização do Aluno: 1 x 2'
    if a == 9:
        return'Localização do Aluno: 2 x 2'
    if a == 10:
        return'Localização do Aluno: 3 x 2'
    if a == 11:
        return'Localização do Aluno: 4 x 2'
    if a == 12:
        return'Localização do Aluno: 5 x 2'
    if a == 13:
        return'Localização do Aluno: 6 x 2'
    if a == 14:
        return'Localização do Aluno: 7 x 2'
    if a == 15:
        return'Localização do Aluno: 1 x 3'
    if a == 16:
        return'Localização do Aluno: 2 x 3'
    if a == 17:
        return'Localização do Aluno: 3 x 3'
    if a == 18:
        return'Localização do Aluno: 4 x 3'
    if a == 19:
        return'Localização do Aluno: 5 x 3'
    if a == 20:
        return'Localização do Aluno: 6 x 3'
    if a == 21:
        return'Localização do Aluno: 7 x 3'

# %%
# Função que trata os valores das linhas e colunas recebidos pelo usuário
def UserTry (t, tipo):
    # Tipo 0 são as listas
    if tipo == 0: 
        # Estabele condição para encerrar o programa caso o valor lido seja 999
        if t == 999:
            return 2

        # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
        elif t > 7 or t < 1:
            #print('O máximo de linhas existentes na lista são 7 e o mínimo 1!\n')
            return 1
        
    # Tipo 1 são as colunas
    elif tipo == 1:
        # Estabele condição para encerrar o programa caso o valor lido seja 999
        if t == 999:
            return 2     
            
        # Encerra o programa caso o usuário selecione valores que excedem os limites da Matriz
        elif t > 3 or t < 1: 
            #print('O máximo de colunas existentes na lista são 3 e o mínimo 1!\n')
            return 1
    
    # Tipo 2 são os nomes
    elif tipo == 2:
        # Estabele condição para encerrar o programa caso o valor lido seja 999
        if nome == '999':
            return 2
            
    else:
        return 0

# %%
# Função que Imprimi os títulos e instruções
def Intro (x):
    if x == 1:
        return'[Opção 1] Insere aluno no dispositivo\n----------------------------------------\nDigite 999 no valor para encerrar'
    if x == 2:
        return'[Opção 2] Libera posição do dispositivo\n----------------------------------------\nDigite 999 no valor para encerrar'
    if x == 3:
        return'[Opção 3] Exibe ocupação no dispositivo\n----------------------------------------'
    if x == 4:
        return'[Opção 4] Listar alunos no dispositivo\n----------------------------------------'
    if x == 9:
        return'### Fim do Programa ###'

# %%
# Lista com espaços 'vazios' para adicionar nomes de guerra
pa = [['*', '*', '*', '*', '*', '*', '*'], ['*', '*', '*', '*', '*', '*', '*'], ['*', '*', '*', '*', '*', '*', '*']]
ent = 0  # Variável que recebe valor do usuário para selecionar opção no menu


# Loop While utilizado para manter o menu atualizando
while ent <= 999:
    
    # Imprimindo texto do menu
    print('Escolha:')
    print('1-Informar posição de aluno no dispositivo.')
    print('2-Liberar posição no dispositivo.')
    print('3-Verificar a ocupação no dispositivo.')
    print('4-Listar alunos no dispositivo de formatura.')
    print('9-Sair do programa.\n')
    
    # Recebendo valor do usuário
    ent = int(input('>'))
    print('\n')

    # Se o usuario selecionar opção 1
    if ent == 1:
        
        # Imprimi os títulos e instruções
        print(Intro(ent))
        
        # Recebe o valor da linha selecionada pelo usuário
        linha = int(input('Linha: '))
        
        # Função que verifica se está tudo ok com o valor inserido pelo usuário
        l = UserTry(linha, 0)
        
        # Se a função retornar 1
        if l == 1:
            # O programa retorna ao menu com um aviso.
            print('O máximo de linhas existentes na matriz são 7 e o mínimo 1!\n')
            
        # Se a função retornar 2
        elif l == 2:
            # O programa retorna ao menu sem aviso.
            print('\n')
        
        else:
            # Recebe o valor da coluna selecionada pelo usuário
            coluna = int(input('Coluna: '))

            # Função que verifica se está tudo ok com o valor inserido pelo usuário
            c = UserTry(coluna, 1)

            # Se a função retornar 1
            if c == 1:
                # O programa retorna ao menu com um aviso.
                print('O máximo de colunas existentes na matriz são 3 e o mínimo 1!\n')

            # Se a função retornar 2
            elif c == 2:
                # O programa retorna ao menu sem aviso.
                print('\n')
            
            else:
                # Recebe o nome de guerra que será adicionado à matriz
                nome = str(input('Nome do Aluno: '))

                # Função que verifica se está tudo ok com o valor inserido pelo usuário
                n = UserTry(nome, 2)

                # Se a função retornar 1
                if n == 1:
                    # O programa retorna ao menu.
                    print('\n')

                # Se a função retornar 2
                elif n == 2:
                    # O programa também retorna ao menu.
                    print('\n')

                # Se nenhum impecílio ocorrer o nome é adicionado a Matriz
                else:    
                    pa[coluna-1][linha-1] = nome
                    print(f'{linha} x {coluna} destinada a {nome} \n')
    
    # Se o usuário selecionar a opção 2
    elif ent == 2:
        
        # Imprimi os títulos e instruções
        print(Intro(ent))
        
        # Recebe o valor da linha selecionada pelo usuário
        linha = int(input('Linha: '))
        
        # Função que verifica se está tudo ok com o valor inserido pelo usuário
        l = UserTry(linha, 0)
        
        # Se a função retornar 1
        if l == 1:
            # O programa retorna ao menu com um aviso.
            print('O máximo de linhas existentes na matriz são 7 e o mínimo 1!\n')
            
        # Se a função retornar 2
        elif l == 2:
            # O programa retorna ao menu sem aviso.
            print('\n')
        
        else:
            # Recebe o valor da coluna selecionada pelo usuário
            coluna = int(input('Coluna: '))

            # Função que verifica se está tudo ok com o valor inserido pelo usuário
            c = UserTry(coluna, 1)

            # Se a função retornar 1
            if c == 1:
                # O programa volta ao menu com um aviso.
                print('O máximo de colunas existentes na matriz são 3 e o mínimo 1!\n')

            # Se a função retornar 2
            elif c == 2:
                # O programa volta ao menu sem aviso.
                print('\n')

            # Se nenhum impecílio ocorrer o nome é adicionado a Matriz
            else:
                pa[coluna-1][linha-1] = '*'
                print(f'{linha} x {coluna} Liberada\n')
    
    # Se o usuário selecionar a opção 3
    elif ent == 3:
        
        # Imprimi os títulos e instruções
        print(Intro(ent))
        
        # Recebe o nome de guerra que será adicionado à matriz
        nome_ = str(input('Nome: '))
        
        # Declarando um vetor 
        v = []
        
        # Gerando um laço for que passa pelas 3 colunas da matriz
        for j in range(3):
            # Outro laço for para passar por cada linha da matriz
            for i in range(7):
                # Verificando se o nome se encontra na matriz
                c = v.count(f'{nome_}')
                # Se o nome estiver na matriz
                if c == 1:
                    # O loop encerra
                    break  
                # Adiciona ao vetor 'v' os valores da matriz até encontrar o nome desejado
                v.append(pa[j][i])
        
        # Se o nome estiver na matriz
        if c == 1:
            # Usando a função 'posicao', que recebe o valor que equivale ao tamanho do vetor v.
            print(f'{posicao(len(v))}\n')
        
        # Se não estiver
        else:
            print(f'O nome {nome_} não foi encontrado na matriz.\n')
    
    # Se o usuário selecionar a opção 4
    elif ent == 4:
        
        # Imprimi os títulos e instruções
        print(Intro(ent))
        
        # Imprimi uma lista 'formatada' com os valores da matriz e os valores das linhas e colunas
        print('             |P A L A N Q U E|\n             -----------------\n')
        print('        1               2               3')
        print('        -               -               -')
        print(f'1       {pa[0][0]:16}{pa[1][0]:16}{pa[2][0]}')
        print(f'2       {pa[0][1]:16}{pa[1][1]:16}{pa[2][1]}')
        print(f'3       {pa[0][2]:16}{pa[1][2]:16}{pa[2][2]}')
        print(f'4       {pa[0][3]:16}{pa[1][3]:16}{pa[2][3]}')
        print(f'5       {pa[0][4]:16}{pa[1][4]:16}{pa[2][4]}')
        print(f'6       {pa[0][5]:16}{pa[1][5]:16}{pa[2][5]}')
        print(f'7       {pa[0][6]:16}{pa[1][6]:16}{pa[2][6]}')
        print('\n(*) = vazio\n')
    
    # Se o usuário selecionar a opção 9
    elif ent == 9:
        
        # Imprimi os títulos e instruções
        print(Intro(ent))
        break
    
    # Se o usuário selecionar um valor que não está descrito no menu 
    elif 4 < ent < 9 or ent > 9:
        
        # Imprimi o aviso e reinicia a seleção
        print('-------------------------------')
        print('| Informe um valor existente! |')
        print('-------------------------------\n')
# Out:
# Escolha:
# 1-Informar posição de aluno no dispositivo.
# 2-Liberar posição no dispositivo.
# 3-Verificar a ocupação no dispositivo.
# 4-Listar alunos no dispositivo de formatura.
# 9-Sair do programa.
#
# >14
#
#
# -------------------------------
# | Informe um valor existente! |
# -------------------------------
#
# Escolha:
# 1-Informar posição de aluno no dispositivo.
# 2-Liberar posição no dispositivo.
# 3-Verificar a ocupação no dispositivo.
# 4-Listar alunos no dispositivo de formatura.
# 9-Sair do programa.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 7>()
#      15 print('9-Sair do programa.\n')
#      17 # Recebendo valor do usuário
# ---> 18 ent = int(input('>'))
#      19 print('\n')
#      21 # Se o usuario selecionar opção 1
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
# ...

# %% [markdown]
# ##
